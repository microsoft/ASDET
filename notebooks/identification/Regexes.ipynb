# %% [markdown]
# # Regex definition and storage

# %% [markdown]
# ## Entity - Regexes
# - Account - SID, EMAIL, NTACCT, GUID
# - Host - DNS
# - IP address - IPV4, IPV6
# - URL - URL
# - Azure resource - RESOURCEID
# - Registry key - REGKEY
# - Domain name (DNS) - DNS
# - File - LXPATH, WINPATH
# - File hash - MD5, SHA1, SHA256

# %%
import json
import re


# re.compile
# pathlib

def write_regexes(data, path="./", fileName="regexes"):
    filePathNameWExt = "./" + path + "/" + fileName + ".json"
    with open(filePathNameWExt, "w") as fp:
        json.dump(data, fp)


data = {
    "DNS_REGEX": {
        "regex": r"^((?=[a-z0-9-]{1,63}\.)[a-z0-9]+(-[a-z0-9]+)*\.){1,126}[a-z]{2,63}$",
        "priority": "1",
        "entity": "host",
    },
    "IPV4_REGEX": {
        "regex": r"^(?P<ipaddress>(?:[0-9]{1,3}\.){3}[0-9]{1,3})$",
        "priority": "0",
        "entity": "ipaddress",
    },
    "IPV6_REGEX": {
        "regex": r"^(?<![:.\w])(?:[A-F0-9]{0,4}:){2,7}[A-F0-9]{0,4}(?![:.\w])$",
        "priority": "0",
        "entity": "ipaddress",
    },
    "URL_REGEX": {
        "regex": r"""
            ^
            (?P<protocol>(https?|ftp|telnet|ldap|file)://)
            (?P<userinfo>([a-z0-9-._~!$&\'()*+,;=:]|%[0-9A-F]{2})*@)?
            (?P<host>([a-z0-9-._~!$&\'()*+,;=]|%[0-9A-F]{2})*)
            (:(?P<port>\d*))?
            (/(?P<path>([^?\#"<>\s]|%[0-9A-F]{2})*/?))?
            (\?(?P<query>([a-z0-9-._~!$&'()*+,;=:/?@]|%[0-9A-F]{2})*))?
            (\#(?P<fragment>([a-z0-9-._~!$&'()*+,;=:/?@]|%[0-9A-F]{2})*))?
            $
            """,
        "priority": "0",
        "entity": "url",
    },
    "MD5_REGEX": {
        "regex": r"^(?:^|[^A-Fa-f0-9])(?P<hash>[A-Fa-f0-9]{32})(?:$|[^A-Fa-f0-9])$",
        "priority": "1",
        "entity": "hash",
    },
    "SHA1_REGEX": {
        "regex": r"^(?:^|[^A-Fa-f0-9])(?P<hash>[A-Fa-f0-9]{40})(?:$|[^A-Fa-f0-9])$",
        "priority": "1",
        "entity": "hash",
    },
    "SHA256_REGEX": {
        "regex": r"^(?:^|[^A-Fa-f0-9])(?P<hash>[A-Fa-f0-9]{64})(?:$|[^A-Fa-f0-9])$",
        "priority": "1",
        "entity": "hash",
    },
    "LXPATH_REGEX": {
        "regex": r"""
            ^(?P<root>/+||[.]+)
            (?P<folder>/(?:[^\\/:*?<>|\r\n]+/)*)
            (?P<file>[^/\0<>|\r\n ]+)$
            """,
        "priority": "2",
        "entity": "file",
    },
    "WINPATH_REGEX": {
        "regex": r"""
            ^(?P<root>[a-z]:|\\\\[a-z0-9_.$-]+||[.]+)
            (?P<folder>\\(?:[^\\/:*?"'<>|\r\n]+\\)*)
            (?P<file>[^\\/*?""<>|\r\n ]+)$
            """,
        "priority": "1",
        "entity": "file",
    },
    "WINPROCESS_REGEX": {
        "regex": r"""
            ^(?P<root>[a-z]:|\\\\[a-z0-9_.$-]+||[.]+)?
            (?P<folder>\\(?:[^\\/:*?"'<>|\r\n]+\\)*)?
            (?P<file>[^\\/*?""<>|\r\n ]+\.exe)$
        """,
        "priority": "1",
        "entity": "process",
    },
    'EMAIL_REGEX': {
        'regex': r"^[\w\d._%+-]+@(?:[\w\d-]+\.)+[\w]{2,}$", 
        'priority': '0', 
        'entity': 'account'
    },
    'RESOURCEID_REGEX': {
        'regex': r"(\/[a-z]+\/)[a-z0-9]{8}(-[a-z0-9]{4}){3}-[a-z0-9]{12}(\/[a-z]+\/).*", 
        'priority': '0', 
        'entity': 'azureresource'
    },
    'NTACCT_REGEX': {
        'regex': r"^([^\/:*?\"<>|]){2,15}\\[^\/:*?\"<>|]{2,15}$", 
        'priority': '0', 
        'entity': 'account'
    },
    'SID_REGEX': {
        'regex': r"^S-[\d]+(-[\d]+)+$", 
        'priority': '1', 
        'entity': 'account'
    },
    'REGKEY_REGEX': {
        'regex': r"""("|'|\s)?(?P<hive>HKLM|HKCU|HKCR|HKU|HKEY_(LOCAL_MACHINE|USERS|CURRENT_USER|CURRENT_CONFIG|CLASSES_ROOT))(?P<key>(\\[^"'\\/]+){1,}\\?)("|'|\s)?""", 
        'priority': '1', 
        'entity': 'registrykey'
    },
    'GUID_REGEX': {
        'regex': r"^[a-z0-9]{8}(-[a-z0-9]{4}){3}-[a-z0-9]{12}$", 
        'priority': '1', 
        'data_format': 'uuid'
    },

}

write_regexes(data)

# %%
def append_regex(name, regex, priority, entity):
    with open ('regexes.json') as json_file:
        data = json.load(json_file)
        y = {name: {'regex': regex, 'priority': priority, 'entity': entity}}
        data.update(y)
    with open ('regexes.json', 'w') as f:
        json.dump(data, f)

# %%
def get_regexes():
    with open('regexes.json') as f:
        return json.load(f)

# %%
entity_regexes = get_regexes()
print(entity_regexes)
# Out:
# {'DNS_REGEX': {'regex': '^((?=[a-z0-9-]{1,63}\\.)[a-z0-9]+(-[a-z0-9]+)*\\.){1,126}[a-z]{2,63}$', 'priority': '1', 'entity': 'host'}, 'IPV4_REGEX': {'regex': '^(?P<ipaddress>(?:[0-9]{1,3}\\.){3}[0-9]{1,3})$', 'priority': '0', 'entity': 'ipaddress'}, 'IPV6_REGEX': {'regex': '^(?<![:.\\w])(?:[A-F0-9]{0,4}:){2,7}[A-F0-9]{0,4}(?![:.\\w])$', 'priority': '0', 'entity': 'ipaddress'}, 'URL_REGEX': {'regex': '\n            ^\n            (?P<protocol>(https?|ftp|telnet|ldap|file)://)\n            (?P<userinfo>([a-z0-9-._~!$&\\\'()*+,;=:]|%[0-9A-F]{2})*@)?\n            (?P<host>([a-z0-9-._~!$&\\\'()*+,;=]|%[0-9A-F]{2})*)\n            (:(?P<port>\\d*))?\n            (/(?P<path>([^?\\#"<>\\s]|%[0-9A-F]{2})*/?))?\n            (\\?(?P<query>([a-z0-9-._~!$&\'()*+,;=:/?@]|%[0-9A-F]{2})*))?\n            (\\#(?P<fragment>([a-z0-9-._~!$&\'()*+,;=:/?@]|%[0-9A-F]{2})*))?\n            $\n            ', 'priority': '0', 'entity': 'url'}, 'MD5_REGEX': {'regex': '^(?:^|[^A-Fa-f0-9])(?P<hash>[A-Fa-f0-9]{32})(?:$|[^A-Fa-f0-9])$', 'priority': '1', 'entity': 'hash'}, 'SHA1_REGEX': {'regex': '^(?:^|[^A-Fa-f0-9])(?P<hash>[A-Fa-f0-9]{40})(?:$|[^A-Fa-f0-9])$', 'priority': '1', 'entity': 'hash'}, 'SHA256_REGEX': {'regex': '^(?:^|[^A-Fa-f0-9])(?P<hash>[A-Fa-f0-9]{64})(?:$|[^A-Fa-f0-9])$', 'priority': '1', 'entity': 'hash'}, 'LXPATH_REGEX': {'regex': '\n            ^(?P<root>/+||[.]+)\n            (?P<folder>/(?:[^\\\\/:*?<>|\\r\\n]+/)*)\n            (?P<file>[^/\\0<>|\\r\\n ]+)$\n            ', 'priority': '2', 'entity': 'file'}, 'WINPATH_REGEX': {'regex': '\n            ^(?P<root>[a-z]:|\\\\\\\\[a-z0-9_.$-]+||[.]+)\n            (?P<folder>\\\\(?:[^\\\\/:*?"\'<>|\\r\\n]+\\\\)*)\n            (?P<file>[^\\\\/*?""<>|\\r\\n ]+)$\n            ', 'priority': '1', 'entity': 'file'}, 'WINPROCESS_REGEX': {'regex': '\n            ^(?P<root>[a-z]:|\\\\\\\\[a-z0-9_.$-]+||[.]+)?\n            (?P<folder>\\\\(?:[^\\\\/:*?"\'<>|\\r\\n]+\\\\)*)?\n            (?P<file>[^\\\\/*?""<>|\\r\\n ]+\\.exe)$\n        ', 'priority': '1', 'entity': 'process'}, 'EMAIL_REGEX': {'regex': '^[\\w\\d._%+-]+@(?:[\\w\\d-]+\\.)+[\\w]{2,}$', 'priority': '0', 'entity': 'account'}, 'RESOURCEID_REGEX': {'regex': '(\\/[a-z]+\\/)[a-z0-9]{8}(-[a-z0-9]{4}){3}-[a-z0-9]{12}(\\/[a-z]+\\/).*', 'priority': '0', 'entity': 'azureresource'}, 'NTACCT_REGEX': {'regex': '^([^\\/:*?\\"<>|]){2,15}\\\\[^\\/:*?\\"<>|]{2,15}$', 'priority': '0', 'entity': 'account'}, 'SID_REGEX': {'regex': '^S-[\\d]+(-[\\d]+)+$', 'priority': '1', 'entity': 'account'}, 'REGKEY_REGEX': {'regex': '("|\'|\\s)?(?P<hive>HKLM|HKCU|HKCR|HKU|HKEY_(LOCAL_MACHINE|USERS|CURRENT_USER|CURRENT_CONFIG|CLASSES_ROOT))(?P<key>(\\\\[^"\'\\\\/]+){1,}\\\\?)("|\'|\\s)?', 'priority': '1', 'entity': 'registrykey'}, 'GUID_REGEX': {'regex': '^[a-z0-9]{8}(-[a-z0-9]{4}){3}-[a-z0-9]{12}$', 'priority': '1', 'data_format': 'uuid'}}

# %% [markdown]
# # Regex application to tables

# %%
# Core MSTICPy initialization for Notebooks
from msticpy.nbtools import nbinit
nbinit.init_notebook(namespace=globals());

# Load query providers (typically you'll be using just one)
qry_prov = QueryProvider("AzureSentinel")
# Out:
# <hr><h4>Starting Notebook initialization...</h4>
# msticpy version installed: 1.0.1 latest published: 1.3.0<br>A newer version of msticpy - 1.3.0 is available.<br>Upgrade with pip install --upgrade msticpy<br> <br>
# Processing imports.... <br>
# Imported: pd (pandas), IPython.get_ipython, IPython.display.display, IPython.display.HTML, IPython.display.Markdown, widgets (ipywidgets), pathlib.Path, plt (matplotlib.pyplot), matplotlib.MatplotlibDeprecationWarning, np (numpy), msticpy.data.QueryProvider, msticpy.nbtools.foliummap.FoliumMap, msticpy.common.utility.md, msticpy.common.utility.md_warn, msticpy.common.wsconfig.WorkspaceConfig, msticpy.datamodel.pivot.Pivot, msticpy.datamodel.entities <br>
# Checking configuration.... <br>
# No errors found.<br><br>The following configuration warnings were found: <br> -------------------------------------------------<br>'TIProviders' section has no settings.<br>'OtherProviders' section has no settings.<br> <br>
# Setting notebook options.... <br>
# <h4>Notebook initialization complete</h4>

# %%
qry_prov.connect(WorkspaceConfig())
# Out:
# <!DOCTYPE html>
#             <html><body>
#             <div style=''>
#             <b>EBUTCZWQS</b>&nbsp;<a href='https://microsoft.com/devicelogin' style='padding: 2px 6px 2px 6px; color: #333333; background-color: #EEEEEE; border-top: 1px solid #CCCCCC; border-right: 1px solid #333333; border-bottom: 1px solid #333333; border-left: 1px solid #CCCCCC' target='verification_url'>Copy code to clipboard and authenticate</a>
#             </div>
#             </body></html>
# <!DOCTYPE html>
#                             <html><body><script>
#
#                                 // close authentication window
#                                 if (kql_MagicUserCodeAuthWindow && kql_MagicUserCodeAuthWindow.opener != null && !kql_MagicUserCodeAuthWindow.closed) {
#                                     kql_MagicUserCodeAuthWindow.close()
#                                 }
#                                 // TODO: make sure, you clear the right cell. BTW, not sure it is a must to do any clearing
#
#                                 // clear output cell
#                                 Jupyter.notebook.clear_output(Jupyter.notebook.get_selected_index())
#
#                                 // TODO: if in run all mode, move to last cell, otherwise move to next cell
#                                 // move to next cell
#
#                             </script></body></html>

# %%
len(qry_prov.schema)
# Out:
# 331

# %%
signin_df = qry_prov.exec_query("SigninLogs | sample 100")
signin_df.head()
# Out:
#                                TenantId SourceSystem  \
# 0  8ecf8077-cf51-4820-aadd-14040956f35d     Azure AD
# 1  8ecf8077-cf51-4820-aadd-14040956f35d     Azure AD
# 2  8ecf8077-cf51-4820-aadd-14040956f35d     Azure AD
# 3  8ecf8077-cf51-4820-aadd-14040956f35d     Azure AD
# 4  8ecf8077-cf51-4820-aadd-14040956f35d     Azure AD
#
#                      TimeGenerated  \
# 0 2021-07-27 11:36:14.794000+00:00
# 1 2021-05-05 10:44:30.585000+00:00
# 2 2021-06-16 15:28:01.513000+00:00
# 3 2021-05-31 13:47:00.875000+00:00
# 4 2021-05-18 10:06:03.226000+00:00
#
#                                                                  ResourceId  \
# 0  /tenants/4b2462a4-bbee-495a-a0e1-f23ae524cc9c/providers/Microsoft.aadiam
# 1  /tenants/4b2462a4-bbee-495a-a0e1-f23ae524cc9c/providers/Microsoft.aadiam
# 2  /tenants/4b2462a4-bbee-495a-a0e1-f23ae524cc9c/providers/Microsoft.aadiam
# 3  /tenants/4b2462a4-bbee-495a-a0e1-f23ae524cc9c/providers/Microsoft.aadiam
# 4  /tenants/4b2462a4-bbee-495a-a0e1-f23ae524cc9c/providers/Microsoft.aadiam
#
#       OperationName OperationVersion    Category ResultType ResultSignature  \
# 0  Sign-in activity              1.0  SignInLogs          0            None
# 1  Sign-in activity              1.0  SignInLogs      16000            None
# 2  Sign-in activity              1.0  SignInLogs      50126            None
# 3  Sign-in activity              1.0  SignInLogs          0            None
# 4  Sign-in activity              1.0  SignInLogs          0            None
#
#                                                           ResultDescription  \
# 0
# 1                                                                     Other
# 2  Invalid username or password or Invalid on-premise username or password.
# 3
# 4
#
#    DurationMs                         CorrelationId          Resource  \
# 0           0  204fa613-b849-4aab-986c-43786bdec271  Microsoft.aadiam
# 1           0  420e8936-b427-4d50-b364-5aaa78e86ba9  Microsoft.aadiam
# 2           0  c8e98a2f-1927-47e5-85f0-02f57bb2c4cf  Microsoft.aadiam
# 3           0  535d4ef9-ad2a-4ad3-b0d5-c6a22f2ce980  Microsoft.aadiam
# 4           0  0f5ad317-0d7a-42d5-bbce-6b7d7b14cd4e  Microsoft.aadiam
#
#       ResourceGroup ResourceProvider             Identity Level Location  \
# 0  Microsoft.aadiam                      Traveler Account     4       RU
# 1  Microsoft.aadiam                         Pavel Morozov     4       RU
# 2  Microsoft.aadiam                   Purview DataCurator     4       US
# 3  Microsoft.aadiam                        Arseny Vasilev     4       RU
# 4  Microsoft.aadiam                    Michał Olczak (PL)     4       PL
#
#       AlternateSignInName                  AppDisplayName  \
# 0                                            Azure Portal
# 1                                            Azure Portal
# 2  purviewdc@seccxp.ninja  Microsoft Azure Purview Studio
# 3                                            Azure Portal
# 4                                            Azure Portal
#
#                                   AppId  \
# 0  c44b4083-3bb0-49c1-b47d-974e53cbdf3c
# 1  c44b4083-3bb0-49c1-b47d-974e53cbdf3c
# 2  632d803a-b0c2-49b4-a944-e13c384c04a8
# 3  c44b4083-3bb0-49c1-b47d-974e53cbdf3c
# 4  c44b4083-3bb0-49c1-b47d-974e53cbdf3c
#
#                                                                                  AuthenticationDetails  \
# 0  [\r\n  {\r\n    "authenticationStepDateTime": "2021-07-27T11:36:14.7946273+00:00",\r\n    "authe...
# 1  [\r\n  {\r\n    "authenticationStepDateTime": "2021-05-05T10:44:30.5857172+00:00",\r\n    "authe...
# 2  [\r\n  {\r\n    "authenticationStepDateTime": "2021-06-16T15:28:01.5131514+00:00",\r\n    "authe...
# 3  [\r\n  {\r\n    "authenticationStepDateTime": "2021-05-31T13:47:00.875543+00:00",\r\n    "authen...
# 4  [\r\n  {\r\n    "authenticationStepDateTime": "2021-05-18T10:06:03.2263377+00:00",\r\n    "authe...
#
#   AuthenticationMethodsUsed  \
# 0
# 1
# 2
# 3
# 4
#
#                                             AuthenticationProcessingDetails  \
# 0  [\r\n  {\r\n    "key": "IsCAEToken",\r\n    "value": "False"\r\n  }\r\n]
# 1  [\r\n  {\r\n    "key": "IsCAEToken",\r\n    "value": "False"\r\n  }\r\n]
# 2  [\r\n  {\r\n    "key": "IsCAEToken",\r\n    "value": "False"\r\n  }\r\n]
# 3  [\r\n  {\r\n    "key": "IsCAEToken",\r\n    "value": "False"\r\n  }\r\n]
# 4  [\r\n  {\r\n    "key": "IsCAEToken",\r\n    "value": "False"\r\n  }\r\n]
#
#     AuthenticationRequirement  ... RiskEventTypes RiskEventTypes_V2  \
# 0  singleFactorAuthentication  ...             []                []
# 1  singleFactorAuthentication  ...             []                []
# 2  singleFactorAuthentication  ...             []                []
# 3  singleFactorAuthentication  ...             []                []
# 4  singleFactorAuthentication  ...             []                []
#
#   RiskLevelAggregated RiskLevelDuringSignIn RiskState  \
# 0                none                  none      none
# 1                none                  none      none
# 2                none                  none      none
# 3                none                  none      none
# 4                none                  none      none
#
#                     ResourceDisplayName                      ResourceIdentity  \
# 0  Windows Azure Service Management API  797f4846-ba00-4fd7-ba43-dac1f8f63013
# 1  Windows Azure Service Management API  797f4846-ba00-4fd7-ba43-dac1f8f63013
# 2                       Microsoft Graph  00000003-0000-0000-c000-000000000000
# 3  Windows Azure Service Management API  797f4846-ba00-4fd7-ba43-dac1f8f63013
# 4  Windows Azure Service Management API  797f4846-ba00-4fd7-ba43-dac1f8f63013
#
#   ServicePrincipalId ServicePrincipalName  \
# 0
# 1
# 2
# 3
# 4
#
#                                                                                                 Status  \
# 0                                                                                     {'errorCode': 0}
# 1                                                       {'errorCode': 16000, 'failureReason': 'Other'}
# 2  {'errorCode': 50126, 'failureReason': 'Invalid username or password or Invalid on-premise userna...
# 3                                                                                     {'errorCode': 0}
# 4                                                                                     {'errorCode': 0}
#
#   TokenIssuerName TokenIssuerType  \
# 0                         AzureAD
# 1                         AzureAD
# 2                         AzureAD
# 3                         AzureAD
# 4                         AzureAD
#
#                                                                                              UserAgent  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.447...
# 1  Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.443...
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.447...
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.443...
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.443...
#
#        UserDisplayName                                UserId  \
# 0     Traveler Account  fac439e8-41d3-414d-b1c6-ea168a1e80b3
# 1        Pavel Morozov  bb8912d4-25b7-4e82-a16f-289774cef163
# 2  Purview DataCurator  ad75bd68-b15a-465b-8192-0bf2ce84095a
# 3       Arseny Vasilev  9267d02c-5f76-40a9-a9eb-b686f3ca47aa
# 4   Michał Olczak (PL)  672885e3-2e3b-4514-a620-4dc1dbc8b095
#
#                              UserPrincipalName  \
# 0  traveleraccount@seccxpninja.onmicrosoft.com
# 1                         pmorozov@viacode.com
# 2                       purviewdc@seccxp.ninja
# 3                         avasilev@viacode.com
# 4                        michal.olczak@pwc.com
#
#                             AADTenantId UserType FlaggedForReview  \
# 0  4b2462a4-bbee-495a-a0e1-f23ae524cc9c   Member             None
# 1  4b2462a4-bbee-495a-a0e1-f23ae524cc9c   Member             None
# 2  4b2462a4-bbee-495a-a0e1-f23ae524cc9c   Member             None
# 3  4b2462a4-bbee-495a-a0e1-f23ae524cc9c    Guest             None
# 4  4b2462a4-bbee-495a-a0e1-f23ae524cc9c    Guest             None
#
#   IPAddressFromResourceProvider        SignInIdentifier SignInIdentifierType  \
# 0
# 1
# 2                                purviewdc@seccxp.ninja
# 3
# 4
#
#                        ResourceTenantId                          HomeTenantId  \
# 0  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 1  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 2  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 3  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  5fccd68a-e65e-46ae-96b1-2d896d680249
# 4  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  513294a0-3e20-41b2-a970-6d30bf1546fa
#
#          Type
# 0  SigninLogs
# 1  SigninLogs
# 2  SigninLogs
# 3  SigninLogs
# 4  SigninLogs
#
# [5 rows x 66 columns]

# %%
secevent_df = qry_prov.exec_query("SecurityEvent | sample 100")
secevent_df.head()
# Out:
#                                TenantId                    TimeGenerated  \
# 0  8ecf8077-cf51-4820-aadd-14040956f35d 2021-06-11 16:12:32.930000+00:00
# 1  8ecf8077-cf51-4820-aadd-14040956f35d 2021-07-27 16:07:34.030000+00:00
# 2  8ecf8077-cf51-4820-aadd-14040956f35d 2021-05-23 15:53:26.993000+00:00
# 3  8ecf8077-cf51-4820-aadd-14040956f35d 2021-07-27 16:07:34.023000+00:00
# 4  8ecf8077-cf51-4820-aadd-14040956f35d 2021-07-27 16:07:34.050000+00:00
#
#   SourceSystem              Account AccountType             Computer  \
# 0   OpsManager               \ADMIN        User           SOC-FW-RDP
# 1   OpsManager  NT AUTHORITY\SYSTEM        User  ADFS01.seccxp.ninja
# 2   OpsManager       \ADMINISTRATOR        User           SOC-FW-RDP
# 3   OpsManager       SECCXP\ADFS01$     Machine  ADFS01.seccxp.ninja
# 4   OpsManager       SECCXP\ADFS01$     Machine  ADFS01.seccxp.ninja
#
#                        EventSourceName  \
# 0  Microsoft-Windows-Security-Auditing
# 1          Microsoft-Windows-AppLocker
# 2  Microsoft-Windows-Security-Auditing
# 3  Microsoft-Windows-Security-Auditing
# 4  Microsoft-Windows-Security-Auditing
#
#                                    Channel   Task Level  \
# 0                                 Security  12544    16
# 1  Microsoft-Windows-AppLocker/EXE and DLL      0     4
# 2                                 Security  12544    16
# 3                                 Security  13312     8
# 4                                 Security  12801     8
#
#                                                                                              EventData  \
# 0
# 1  <UserData xmlns="http://schemas.microsoft.com/win/2004/08/events/event">\r\n  <RuleAndFileData x...
# 2
# 3
# 4  <EventData xmlns="http://schemas.microsoft.com/win/2004/08/events/event">\r\n  <Data Name="Subje...
#
#    EventID                                         Activity  \
# 0     4625              4625 - An account failed to log on.
# 1     8002             8002 - A process was allowed to run.
# 2     4625              4625 - An account failed to log on.
# 3     4688           4688 - A new process has been created.
# 4     4663  4663 - An attempt was made to access an object.
#
#                        SourceComputerId                         EventOriginId  \
# 0  41502da5-21b7-48ec-81c9-baeea8d7d669  5bb62b73-62d6-48d0-98b7-8da16a75b407
# 1  20ca974d-fade-4e11-abc4-6fc11997180a  23a7b5c5-d8fa-42a5-b4a4-9b7f04af9653
# 2  41502da5-21b7-48ec-81c9-baeea8d7d669  746bd43b-ce81-45f9-ad53-5d149e2b003e
# 3  20ca974d-fade-4e11-abc4-6fc11997180a  edbab4c6-0323-4552-8c83-de0afed8a790
# 4  20ca974d-fade-4e11-abc4-6fc11997180a  6f4e61a1-5a1a-4b2f-9996-ade3bed99b63
#
#                                      MG                    TimeCollected  \
# 0  00000000-0000-0000-0000-000000000001 2021-06-11 16:12:35.274000+00:00
# 1  00000000-0000-0000-0000-000000000001 2021-07-27 16:08:05.355000+00:00
# 2  00000000-0000-0000-0000-000000000001 2021-05-23 15:53:31.542000+00:00
# 3  00000000-0000-0000-0000-000000000001 2021-07-27 16:08:05.355000+00:00
# 4  00000000-0000-0000-0000-000000000001 2021-07-27 16:08:05.355000+00:00
#
#                         ManagementGroupName       AccessList AccessMask  \
# 0  AOI-8ecf8077-cf51-4820-aadd-14040956f35d
# 1  AOI-8ecf8077-cf51-4820-aadd-14040956f35d
# 2  AOI-8ecf8077-cf51-4820-aadd-14040956f35d
# 3  AOI-8ecf8077-cf51-4820-aadd-14040956f35d
# 4  AOI-8ecf8077-cf51-4820-aadd-14040956f35d  %%4432 \t\t\t\t        0x1
#
#   AccessReason AccountDomain AccountExpires AccountName  \
# 0
# 1
# 2
# 3
# 4
#
#   AccountSessionIdentifier  ... TargetUserName TargetUserSid TemplateContent  \
# 0                           ...          ADMIN       S-1-0-0
# 1                           ...
# 2                           ...  ADMINISTRATOR       S-1-0-0
# 3                           ...              -       S-1-0-0
# 4                           ...
#
#   TemplateDSObjectFQDN TemplateInternalName  TemplateOID  \
# 0
# 1
# 2
# 3
# 4
#
#    TemplateSchemaVersion TemplateVersion TokenElevationType  \
# 0
# 1
# 2
# 3                                                    %%1936
# 4
#
#   TransmittedServices  UserAccountControl UserParameters UserPrincipalName  \
# 0                   -
# 1
# 2                   -
# 3
# 4
#
#   UserWorkstations VirtualAccount VendorIds Workstation WorkstationName  \
# 0                                                                     -
# 1
# 2                                                                     -
# 3
# 4
#
#   PartitionKey RowKey StorageAccount AzureDeploymentID AzureTableName  \
# 0
# 1
# 2
# 3
# 4
#
#             Type  \
# 0  SecurityEvent
# 1  SecurityEvent
# 2  SecurityEvent
# 3  SecurityEvent
# 4  SecurityEvent
#
#                                                                                            _ResourceId
# 0  /subscriptions/d1d8779d-38d7-4f06-91db-9cbc8de0176f/resourcegroups/soc-fortinet/providers/micros...
# 1  /subscriptions/d1d8779d-38d7-4f06-91db-9cbc8de0176f/resourcegroups/simuland/providers/microsoft....
# 2  /subscriptions/d1d8779d-38d7-4f06-91db-9cbc8de0176f/resourcegroups/soc-fortinet/providers/micros...
# 3  /subscriptions/d1d8779d-38d7-4f06-91db-9cbc8de0176f/resourcegroups/simuland/providers/microsoft....
# 4  /subscriptions/d1d8779d-38d7-4f06-91db-9cbc8de0176f/resourcegroups/simuland/providers/microsoft....
#
# [5 rows x 225 columns]

# %%
offact_df = qry_prov.exec_query("OfficeActivity | sample 100")
offact_df.head()
# Out:
#                                TenantId Application UserDomain UserAgent  \
# 0  8ecf8077-cf51-4820-aadd-14040956f35d
# 1  8ecf8077-cf51-4820-aadd-14040956f35d
# 2  8ecf8077-cf51-4820-aadd-14040956f35d
# 3  8ecf8077-cf51-4820-aadd-14040956f35d
# 4  8ecf8077-cf51-4820-aadd-14040956f35d
#
#       RecordType             TimeGenerated          Operation  \
# 0             50 2021-07-27 11:11:58+00:00  MailItemsAccessed
# 1             50 2021-07-07 13:29:47+00:00  MailItemsAccessed
# 2             50 2021-07-27 11:18:13+00:00  MailItemsAccessed
# 3  ExchangeAdmin 2021-06-11 11:18:27+00:00           Set-User
# 4             50 2021-07-27 11:18:13+00:00  MailItemsAccessed
#
#                          OrganizationId                       OrganizationId_  \
# 0  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 1  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 2  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 3  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 4  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
#
#   UserType                                                          UserKey  \
# 0  Regular                                                 100320003F88D275
# 1  Regular                                                 10032000D105B030
# 2  Regular                                                 100320003F8A6FC7
# 3  DcAdmin  NT AUTHORITY\SYSTEM (Microsoft.Exchange.Management.ForwardSync)
# 4  Regular                                                 100320003F8A6FC7
#
#   OfficeWorkload ResultStatus ResultReasonType  \
# 0       Exchange    Succeeded        Succeeded
# 1       Exchange    Succeeded        Succeeded
# 2       Exchange    Succeeded        Succeeded
# 3       Exchange         True             True
# 4       Exchange    Succeeded        Succeeded
#
#                                                                                         OfficeObjectId  \
# 0
# 1
# 2
# 3  NAMPR06A007.PROD.OUTLOOK.COM/Microsoft Exchange Hosted Organizations/seccxpninja.onmicrosoft.com...
# 4
#
#                                                             UserId  \
# 0                                  seb@seccxpninja.onmicrosoft.com
# 1                               JBritt@seccxpninja.onmicrosoft.com
# 2                                              MeganB@seccxp.ninja
# 3  NT AUTHORITY\SYSTEM (Microsoft.Exchange.Management.ForwardSync)
# 4                                              MeganB@seccxp.ninja
#
#                                                            UserId_ ClientIP  \
# 0                                  seb@seccxpninja.onmicrosoft.com
# 1                               JBritt@seccxpninja.onmicrosoft.com
# 2                                              MeganB@seccxp.ninja
# 3  NT AUTHORITY\SYSTEM (Microsoft.Exchange.Management.ForwardSync)
# 4                                              MeganB@seccxp.ninja
#
#   ClientIP_ Scope Site_ ItemType EventSource Source_Name MachineDomainInfo  \
# 0
# 1
# 2
# 3
# 4
#
#    ... ChannelType ChannelName ChannelGuid ExtraProperties AddOnType  \
# 0  ...                                                None
# 1  ...                                                None
# 2  ...                                                None
# 3  ...                                                None
# 4  ...                                                None
#
#   AddonName TabType Name OldValue NewValue ItemName ChatThreadId ChatName  \
# 0
# 1
# 2
# 3
# 4
#
#   CommunicationType AADGroupId AddOnGuid AppDistributionMode TargetUserId  \
# 0
# 1
# 2
# 3
# 4
#
#   OperationScope AzureADAppId  \
# 0
# 1
# 2
# 3
# 4
#
#                                                                         OperationProperties  \
# 0  [{'Name': 'MailAccessType', 'Value': 'Bind'}, {'Name': 'IsThrottled', 'Value': 'False'}]
# 1  [{'Value': 'Bind', 'Name': 'MailAccessType'}, {'Value': 'False', 'Name': 'IsThrottled'}]
# 2  [{'Name': 'MailAccessType', 'Value': 'Bind'}, {'Name': 'IsThrottled', 'Value': 'False'}]
# 3                                                                                      None
# 4  [{'Name': 'MailAccessType', 'Value': 'Bind'}, {'Name': 'IsThrottled', 'Value': 'False'}]
#
#                                   AppId                           ClientAppId  \
# 0  7ab7862c-4c57-491e-8a45-d52a7e023983
# 1  7a5fbd1c-3e6d-461a-9075-83049393b3a7  7a5fbd1c-3e6d-461a-9075-83049393b3a7
# 2  414a677a-e50f-46ea-b89c-aebb8a9efbe2
# 3
# 4  414a677a-e50f-46ea-b89c-aebb8a9efbe2
#
#              Type _ResourceId
# 0  OfficeActivity
# 1  OfficeActivity
# 2  OfficeActivity
# 3  OfficeActivity
# 4  OfficeActivity
#
# [5 rows x 131 columns]

# %%
comsec_df = qry_prov.exec_query("CommonSecurityLog | sample 1000")
comsec_df.head()
# Out:
#                                TenantId SourceSystem  \
# 0  8ecf8077-cf51-4820-aadd-14040956f35d   OpsManager
# 1  8ecf8077-cf51-4820-aadd-14040956f35d   OpsManager
# 2  8ecf8077-cf51-4820-aadd-14040956f35d   OpsManager
# 3  8ecf8077-cf51-4820-aadd-14040956f35d   OpsManager
# 4  8ecf8077-cf51-4820-aadd-14040956f35d   OpsManager
#
#                      TimeGenerated                 ReceiptTime  \
# 0 2021-05-27 10:13:41.583000+00:00
# 1 2021-07-07 03:01:29.513000+00:00
# 2 2021-06-03 17:45:12.266000+00:00  $cefformatted-receive_time
# 3 2021-07-23 01:45:34.986000+00:00  $cefformatted-receive_time
# 4 2021-07-27 15:39:32.680000+00:00
#
#          DeviceVendor DeviceProduct DeviceEventClassID LogSeverity  \
# 0            Fortinet     Fortigate              00013           3
# 1            Fortinet     Fortigate              28704           2
# 2  Palo Alto Networks        PAN-OS                end           1
# 3  Palo Alto Networks        PAN-OS                end           1
# 4            Fortinet     Fortigate              28704           2
#
#   OriginalLogSeverity DeviceAction SimplifiedDeviceAction Computer  \
# 0
# 1
# 2
# 3
# 4
#
#   CommunicationDirection DeviceFacility  DestinationPort DestinationIP  \
# 0                                                 3389.0      10.0.0.5
# 1                      1                           443.0     20.44.8.3
# 2                                                    NaN      10.6.1.5
# 3                                                    NaN      10.6.1.5
# 4                      0                           443.0   20.44.8.204
#
#   DeviceAddress DeviceName                     Message Protocol  SourcePort  \
# 0                                                             6     57487.0
# 1                           Cloud.IT: Microsoft.Azure,        6     51002.0
# 2                                                                       NaN
# 3                                                                       NaN
# 4                           Web.Client: HTTPS.BROWSER,        6     46320.0
#
#         SourceIP RemoteIP RemotePort MaliciousIP  ...  DeviceCustomString4  \
# 0   91.223.67.13                                  ...
# 1       10.0.1.5                                  ...
# 2   40.76.235.24                                  ...
# 3  20.51.113.252                                  ...
# 4       10.0.1.5                                  ...
#
#   DeviceCustomString4Label DeviceCustomString5 DeviceCustomString5Label  \
# 0
# 1
# 2
# 3
# 4
#
#   DeviceCustomString6  DeviceCustomString6Label  DeviceCustomDate1  \
# 0
# 1
# 2
# 3
# 4
#
#   DeviceCustomDate1Label DeviceCustomDate2 DeviceCustomDate2Label FlexDate1  \
# 0
# 1
# 2
# 3
# 4
#
#    FlexDate1Label FlexNumber1 FlexNumber1Label FlexNumber2  FlexNumber2Label  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#   FlexString1 FlexString1Label FlexString2 FlexString2Label  \
# 0
# 1
# 2
# 3
# 4
#
#                                                                                   AdditionalExtensions  \
# 0  FortinetFortiGateeventtime=1622110543134663766;FortinetFortiGatetz=-0700;FortinetFortiGatelogid=...
# 1  FortinetFortiGateeventtime=1625626912883535736;FortinetFortiGatetz=-0700;FortinetFortiGatelogid=...
# 2
# 3
# 4  FortinetFortiGateeventtime=1627400380074752837;FortinetFortiGatetz=-0700;FortinetFortiGatelogid=...
#
#   StartTime EndTime               Type  \
# 0       NaT     NaT  CommonSecurityLog
# 1       NaT     NaT  CommonSecurityLog
# 2       NaT     NaT  CommonSecurityLog
# 3       NaT     NaT  CommonSecurityLog
# 4       NaT     NaT  CommonSecurityLog
#
#                                                                                            _ResourceId
# 0  /subscriptions/d1d8779d-38d7-4f06-91db-9cbc8de0176f/resourcegroups/soc-fortinet/providers/micros...
# 1  /subscriptions/d1d8779d-38d7-4f06-91db-9cbc8de0176f/resourcegroups/soc-fortinet/providers/micros...
# 2  /subscriptions/d1d8779d-38d7-4f06-91db-9cbc8de0176f/resourcegroups/soc-fortinet/providers/micros...
# 3  /subscriptions/d1d8779d-38d7-4f06-91db-9cbc8de0176f/resourcegroups/soc-fortinet/providers/micros...
# 4  /subscriptions/d1d8779d-38d7-4f06-91db-9cbc8de0176f/resourcegroups/soc-fortinet/providers/micros...
#
# [5 rows x 152 columns]

# %%
from collections import defaultdict

def match_regexes(data, debug=False):
    """Function to apply every regex to every column in the given table.

    Args:
        data (DataFrame): A table/log queried from the connected Azure Sentinel workspace.
        debug (bool, optional): If True, prints the columns for which no match was found. Defaults to False.

    Returns:
        Dictionary: {Column: {Regex: (Match ratio excluding blanks, Total match ratio)}}
    """
    # Dictionary to store results
    full_matches = {}
    # Iterate over each column   
    for col in data.columns:
        # Skip non-string columns
        if data[col].dtype != np.dtype("O"):
            if debug:
                print(f" -- col {col} is type {data[col].dtype}. Skipping")
            continue
        # Iterate over every regex
        for name, regex in entity_regexes.items():
            # Try the regex on the column
            match_series = data[col].str.match(regex['regex'], case=False, flags=re.VERBOSE)
            # If there are more than zero rows in the table
            if len(match_series) > 0:
                # Calculate the match ratios, including blanks (total_match_ratio) 
                # and not including blanks (match_ratio)
                total_match_ratio = match_series.sum() / len(match_series)
                blanks_df = data[col].str.strip() == ""
                num_non_blanks = len(match_series) - blanks_df.sum()
                match_ratio = match_series.sum() / num_non_blanks if num_non_blanks > 0 else total_match_ratio
                # If at least one entry in the column matched the regex 
                if total_match_ratio > 0:
                    # Add the column, regex, and match ratios to the dict
                    # If this column has already matched with a regex
                    if col in full_matches:
                        full_matches[col][name] = match_ratio, total_match_ratio
                    else:
                        full_matches[col] = {}
                        full_matches[col][name] = match_ratio, total_match_ratio
        if col not in full_matches and debug:
            print(f" -- col {col} no match found")
    return full_matches

# %%
table_regexes = {}
table_regexes["SigninLogs"] = match_regexes(signin_df)
table_regexes["SecurityEvent"] = match_regexes(secevent_df)
table_regexes["OfficeActivity"] = match_regexes(offact_df)
table_regexes["CommonSecurityLog"] = match_regexes(comsec_df)

import pprint
for table, cols in table_regexes.items():
    print(table)  
    print("-" * len(table))
    pprint.pprint(cols)
# Out:
# SigninLogs
# ----------
# {'AADTenantId': {'GUID_REGEX': (1.0, 1.0)},
#  'AlternateSignInName': {'EMAIL_REGEX': (1.0, 0.34)},
#  'AppDisplayName': {'DNS_REGEX': (0.01, 0.01)},
#  'AppId': {'GUID_REGEX': (1.0, 1.0)},
#  'CorrelationId': {'GUID_REGEX': (1.0, 1.0)},
#  'HomeTenantId': {'GUID_REGEX': (1.0, 0.98)},
#  'IPAddress': {'IPV4_REGEX': (0.94, 0.94), 'IPV6_REGEX': (0.06, 0.06)},
#  'Id': {'GUID_REGEX': (1.0, 1.0)},
#  'OriginalRequestId': {'GUID_REGEX': (1.0, 1.0)},
#  'Resource': {'DNS_REGEX': (1.0, 1.0)},
#  'ResourceGroup': {'DNS_REGEX': (1.0, 1.0)},
#  'ResourceId': {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)},
#  'ResourceIdentity': {'GUID_REGEX': (1.0, 0.95)},
#  'ResourceTenantId': {'GUID_REGEX': (1.0, 1.0)},
#  'SignInIdentifier': {'EMAIL_REGEX': (1.0, 0.34)},
#  'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#  'UserId': {'GUID_REGEX': (1.0, 1.0)},
#  'UserPrincipalName': {'EMAIL_REGEX': (1.0, 1.0)}}
# SecurityEvent
# -------------
# {'Account': {'NTACCT_REGEX': (0.6923076923076923, 0.63),
#              'WINPATH_REGEX': (0.3076923076923077, 0.28)},
#  'Computer': {'DNS_REGEX': (0.51, 0.51)},
#  'EventOriginId': {'GUID_REGEX': (1.0, 1.0)},
#  'FileHash': {'SHA256_REGEX': (1.0, 0.28)},
#  'FilePath': {'NTACCT_REGEX': (0.6428571428571429, 0.18)},
#  'IpAddress': {'IPV4_REGEX': (0.9444444444444444, 0.34)},
#  'LogonGuid': {'GUID_REGEX': (1.0, 0.02)},
#  'MG': {'GUID_REGEX': (1.0, 1.0)},
#  'MandatoryLabel': {'SID_REGEX': (1.0, 0.15)},
#  'NewProcessName': {'WINPATH_REGEX': (1.0, 0.15),
#                     'WINPROCESS_REGEX': (1.0, 0.15)},
#  'ObjectName': {'WINPATH_REGEX': (0.75, 0.06)},
#  'ParentProcessName': {'WINPATH_REGEX': (1.0, 0.15),
#                        'WINPROCESS_REGEX': (1.0, 0.15)},
#  'Process': {'DNS_REGEX': (0.6091954022988506, 0.53),
#              'WINPROCESS_REGEX': (0.6091954022988506, 0.53)},
#  'ProcessName': {'WINPATH_REGEX': (0.22727272727272727, 0.1),
#                  'WINPROCESS_REGEX': (0.22727272727272727, 0.1)},
#  'SourceComputerId': {'GUID_REGEX': (1.0, 1.0)},
#  'SubjectAccount': {'NTACCT_REGEX': (0.4603174603174603, 0.29)},
#  'SubjectUserSid': {'SID_REGEX': (1.0, 0.63)},
#  'TargetAccount': {'NTACCT_REGEX': (0.18867924528301888, 0.1),
#                    'WINPATH_REGEX': (0.5283018867924528, 0.28)},
#  'TargetLogonGuid': {'GUID_REGEX': (1.0, 0.01)},
#  'TargetUser': {'SID_REGEX': (1.0, 0.28)},
#  'TargetUserSid': {'SID_REGEX': (1.0, 0.5)},
#  'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#  '_ResourceId': {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)}}
# OfficeActivity
# --------------
# {'AADGroupId': {'GUID_REGEX': (1.0, 0.02)},
#  'AppId': {'GUID_REGEX': (1.0, 0.51)},
#  'ClientAppId': {'GUID_REGEX': (1.0, 0.17)},
#  'ClientIP': {'IPV4_REGEX': (0.5666666666666667, 0.17),
#               'IPV6_REGEX': (0.1, 0.03)},
#  'ClientIP_': {'IPV4_REGEX': (0.5666666666666667, 0.17),
#                'IPV6_REGEX': (0.1, 0.03)},
#  'Client_IPAddress': {'IPV4_REGEX': (0.7727272727272727, 0.34),
#                       'IPV6_REGEX': (0.22727272727272727, 0.1)},
#  'LogonUserSid': {'SID_REGEX': (1.0, 0.44)},
#  'MailboxGuid': {'GUID_REGEX': (1.0, 0.44)},
#  'MailboxOwnerSid': {'SID_REGEX': (1.0, 0.44)},
#  'MailboxOwnerUPN': {'EMAIL_REGEX': (1.0, 0.44)},
#  'OfficeId': {'GUID_REGEX': (1.0, 1.0)},
#  'OfficeObjectId': {'GUID_REGEX': (0.09259259259259259, 0.05),
#                     'URL_REGEX': (0.1111111111111111, 0.06)},
#  'OrganizationId': {'GUID_REGEX': (1.0, 1.0)},
#  'OrganizationId_': {'GUID_REGEX': (1.0, 1.0)},
#  'OrganizationName': {'DNS_REGEX': (1.0, 0.76)},
#  'Site_': {'GUID_REGEX': (1.0, 0.17)},
#  'Site_Url': {'URL_REGEX': (1.0, 0.14)},
#  'Site_Url_': {'URL_REGEX': (1.0, 0.14)},
#  'SourceFileName': {'DNS_REGEX': (0.15384615384615385, 0.02)},
#  'SourceFileName_': {'DNS_REGEX': (0.15384615384615385, 0.02)},
#  'SourceRecordId': {'GUID_REGEX': (1.0, 1.0)},
#  'TargetUserOrGroupName': {'SHA256_REGEX': (0.5, 0.02)},
#  'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#  'UserId': {'EMAIL_REGEX': (0.59, 0.59), 'NTACCT_REGEX': (0.1, 0.1)},
#  'UserId_': {'EMAIL_REGEX': (0.59, 0.59), 'NTACCT_REGEX': (0.1, 0.1)},
#  'UserKey': {'GUID_REGEX': (0.02, 0.02), 'NTACCT_REGEX': (0.1, 0.1)}}
# CommonSecurityLog
# -----------------
# {'DestinationHostName': {'DNS_REGEX': (0.9893162393162394, 0.463),
#                          'IPV4_REGEX': (0.004273504273504274, 0.002)},
#  'DestinationIP': {'IPV4_REGEX': (1.0, 1.0)},
#  'DestinationTranslatedAddress': {'IPV4_REGEX': (1.0, 0.121)},
#  'DeviceCustomString5': {'DNS_REGEX': (0.00641025641025641, 0.003)},
#  'RequestURL': {'DNS_REGEX': (0.006191950464396285, 0.002)},
#  'SourceIP': {'IPV4_REGEX': (0.997, 0.997)},
#  'SourceTranslatedAddress': {'IPV4_REGEX': (1.0, 0.57)},
#  'SourceUserName': {'EMAIL_REGEX': (0.8311965811965812, 0.389)},
#  'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#  '_ResourceId': {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)}}

# %%
def table_match_to_html(table_name, show_guids=False):
    """Return table column matches as HTML table."""
    if table_name not in table_regexes:
        return HTML("No data")
    
    # Create html table header
    table_html = ["<table><thead><tr><th>Column</th><th>Matches</th></tr></thead><tbody>"]

    for col, matches in table_regexes[table_name].items():
        col_html = {}
        for rgx_match, perc_match in matches.items():
            if rgx_match == "GUID_REGEX" and not show_guids:
                continue
            # Get the entity name and priority for this match
            entity_name = entity_regexes.get(rgx_match, {}).get("entity")
            regex_priority = entity_regexes.get(rgx_match, {}).get("priority", 0)
            if not entity_name:
                entity_name = rgx_match
            # Add a row for the column (using a dictionary since we later want to sort
            # based on priority)
            col_html[regex_priority] = (
                f"<b>{entity_name}</b> [p:{regex_priority}] "
                f"(matched {rgx_match} {perc_match[0] * 100:0.1f}%,  "
                f"all rows {perc_match[1] * 100:0.1f}%) "
            )
        # sort the different matches by priority
        sorted_by_pri = [value for key, value in sorted(col_html.items(), key=lambda item: item[0])]
        # join the matches with some space separators
        cols = "&nbsp;&nbsp;".join(sorted_by_pri)
        # add this as an html table row to the table list
        table_html.append(f"<tr><td><b>{col}</b></td><td>{cols}</td><tr>")
    # add a text heading
    header = "<h2>Column entities</h2>"
    # build and return the table html
    return HTML(f"{header} {''.join(table_html)}</tbody></table>")


nbwidgets.SelectItem(item_list=list(qry_prov.schema.keys()), height="300px", action=table_match_to_html)
# Out:
# VBox(children=(Text(value='', description='Filter:', style=DescriptionStyle(description_width='initial')), Sel…
# <hr>
# <h2>Column entities</h2> <table><thead><tr><th>Column</th><th>Matches</th></tr></thead><tbody><tr><td><b>TenantId</b></td><td></td><tr><tr><td><b>Account</b></td><td><b>account</b> [p:0] (matched NTACCT_REGEX 69.2%,  all rows 63.0%) &nbsp;&nbsp;<b>file</b> [p:1] (matched WINPATH_REGEX 30.8%,  all rows 28.0%) </td><tr><tr><td><b>Computer</b></td><td><b>host</b> [p:1] (matched DNS_REGEX 51.0%,  all rows 51.0%) </td><tr><tr><td><b>SourceComputerId</b></td><td></td><tr><tr><td><b>EventOriginId</b></td><td></td><tr><tr><td><b>MG</b></td><td></td><tr><tr><td><b>FileHash</b></td><td><b>hash</b> [p:1] (matched SHA256_REGEX 100.0%,  all rows 28.0%) </td><tr><tr><td><b>FilePath</b></td><td><b>account</b> [p:0] (matched NTACCT_REGEX 64.3%,  all rows 18.0%) </td><tr><tr><td><b>IpAddress</b></td><td><b>ipaddress</b> [p:0] (matched IPV4_REGEX 94.4%,  all rows 34.0%) </td><tr><tr><td><b>LogonGuid</b></td><td></td><tr><tr><td><b>MandatoryLabel</b></td><td><b>account</b> [p:1] (matched SID_REGEX 100.0%,  all rows 15.0%) </td><tr><tr><td><b>NewProcessName</b></td><td><b>process</b> [p:1] (matched WINPROCESS_REGEX 100.0%,  all rows 15.0%) </td><tr><tr><td><b>ObjectName</b></td><td><b>file</b> [p:1] (matched WINPATH_REGEX 75.0%,  all rows 6.0%) </td><tr><tr><td><b>ParentProcessName</b></td><td><b>process</b> [p:1] (matched WINPROCESS_REGEX 100.0%,  all rows 15.0%) </td><tr><tr><td><b>Process</b></td><td><b>process</b> [p:1] (matched WINPROCESS_REGEX 60.9%,  all rows 53.0%) </td><tr><tr><td><b>ProcessName</b></td><td><b>process</b> [p:1] (matched WINPROCESS_REGEX 22.7%,  all rows 10.0%) </td><tr><tr><td><b>SubjectAccount</b></td><td><b>account</b> [p:0] (matched NTACCT_REGEX 46.0%,  all rows 29.0%) </td><tr><tr><td><b>SubjectUserSid</b></td><td><b>account</b> [p:1] (matched SID_REGEX 100.0%,  all rows 63.0%) </td><tr><tr><td><b>TargetAccount</b></td><td><b>account</b> [p:0] (matched NTACCT_REGEX 18.9%,  all rows 10.0%) &nbsp;&nbsp;<b>file</b> [p:1] (matched WINPATH_REGEX 52.8%,  all rows 28.0%) </td><tr><tr><td><b>TargetLogonGuid</b></td><td></td><tr><tr><td><b>TargetUser</b></td><td><b>account</b> [p:1] (matched SID_REGEX 100.0%,  all rows 28.0%) </td><tr><tr><td><b>TargetUserSid</b></td><td><b>account</b> [p:1] (matched SID_REGEX 100.0%,  all rows 50.0%) </td><tr><tr><td><b>_ResourceId</b></td><td><b>azureresource</b> [p:0] (matched RESOURCEID_REGEX 100.0%,  all rows 100.0%) &nbsp;&nbsp;<b>file</b> [p:2] (matched LXPATH_REGEX 100.0%,  all rows 100.0%) </td><tr></tbody></table>

# %% [markdown]
# ## Modification of match_regexes function for partial (substring) matches

# %%
from collections import defaultdict

def match_regexes_partial(data, debug=False):
    full_matches = {}
    for col in data.columns:

        if data[col].dtype != np.dtype("O"):
            if debug:
                print(f" -- col {col} is type {data[col].dtype}. Skipping")
            continue
            
        for name, regex in entity_regexes.items():
            # strip off ^ and $ delimiters
            part_regex = re.sub(r"^\s*\^(.*)\s*\$\s*$", r"\1", regex["regex"])
            match_series = data[col].str.match(part_regex, case=False, flags=re.VERBOSE)
            
            if len(match_series) > 0:
                match_ratio = match_series.sum() / len(match_series)
                blanks_df = data[col].str.strip() == ""
                num_non_blanks = len(match_series) - blanks_df.sum()
                true_match_ratio = match_series.sum() / num_non_blanks if num_non_blanks > 0 else match_ratio
                if match_ratio > 0:
                    if col in full_matches:
                        full_matches[col][name] = true_match_ratio
                    else:
                        full_matches[col] = {}
                        full_matches[col][name] = true_match_ratio
                
        if col not in full_matches and debug:
            print(f" -- col {col} no match found")
    return full_matches

# %%
table_regexes_part = {}
table_regexes_part["SigninLogs"] = match_regexes_partial(signin_df)
table_regexes_part["SecurityEvent"] = match_regexes_partial(secevent_df)
table_regexes_part["OfficeActivity"] = match_regexes_partial(offact_df)
table_regexes_part["CommonSecurityLog"] = match_regexes_partial(comsec_df)

import pprint
for table, cols in table_regexes_part.items():
    print(table)
    
    print("-" * len(table))
    pprint.pprint(cols)
# Out:
# SigninLogs
# ----------
# {'AADTenantId': {'GUID_REGEX': 1.0},
#  'AlternateSignInName': {'EMAIL_REGEX': 1.0},
#  'AppDisplayName': {'DNS_REGEX': 0.01},
#  'AppId': {'GUID_REGEX': 1.0},
#  'CorrelationId': {'GUID_REGEX': 1.0},
#  'HomeTenantId': {'GUID_REGEX': 1.0},
#  'IPAddress': {'IPV4_REGEX': 0.94, 'IPV6_REGEX': 0.06},
#  'Id': {'GUID_REGEX': 1.0},
#  'OriginalRequestId': {'GUID_REGEX': 1.0},
#  'Resource': {'DNS_REGEX': 1.0},
#  'ResourceGroup': {'DNS_REGEX': 1.0},
#  'ResourceId': {'LXPATH_REGEX': 1.0, 'RESOURCEID_REGEX': 1.0},
#  'ResourceIdentity': {'GUID_REGEX': 1.0},
#  'ResourceTenantId': {'GUID_REGEX': 1.0},
#  'SignInIdentifier': {'EMAIL_REGEX': 1.0},
#  'TenantId': {'GUID_REGEX': 1.0},
#  'UserId': {'GUID_REGEX': 1.0},
#  'UserPrincipalName': {'DNS_REGEX': 0.09, 'EMAIL_REGEX': 1.0}}
# SecurityEvent
# -------------
# {'Account': {'NTACCT_REGEX': 0.6923076923076923,
#              'WINPATH_REGEX': 0.3076923076923077},
#  'AdditionalInfo2': {'NTACCT_REGEX': 1.0},
#  'Computer': {'DNS_REGEX': 0.51},
#  'EventOriginId': {'GUID_REGEX': 1.0},
#  'FileHash': {'SHA256_REGEX': 1.0},
#  'FilePath': {'NTACCT_REGEX': 1.0},
#  'IpAddress': {'IPV4_REGEX': 0.9444444444444444},
#  'LogonGuid': {'GUID_REGEX': 1.0},
#  'MG': {'GUID_REGEX': 1.0},
#  'MandatoryLabel': {'SID_REGEX': 1.0},
#  'NewProcessName': {'WINPATH_REGEX': 1.0, 'WINPROCESS_REGEX': 1.0},
#  'ObjectName': {'NTACCT_REGEX': 1.0, 'WINPATH_REGEX': 0.75},
#  'ParentProcessName': {'WINPATH_REGEX': 1.0, 'WINPROCESS_REGEX': 1.0},
#  'Process': {'DNS_REGEX': 0.6091954022988506,
#              'WINPROCESS_REGEX': 0.6091954022988506},
#  'ProcessName': {'WINPATH_REGEX': 0.22727272727272727,
#                  'WINPROCESS_REGEX': 0.22727272727272727},
#  'SourceComputerId': {'GUID_REGEX': 1.0},
#  'SubjectAccount': {'NTACCT_REGEX': 0.4603174603174603},
#  'SubjectUserSid': {'SID_REGEX': 1.0},
#  'TargetAccount': {'NTACCT_REGEX': 0.18867924528301888,
#                    'WINPATH_REGEX': 0.5283018867924528},
#  'TargetLogonGuid': {'GUID_REGEX': 1.0},
#  'TargetUser': {'SID_REGEX': 1.0},
#  'TargetUserSid': {'SID_REGEX': 1.0},
#  'TenantId': {'GUID_REGEX': 1.0},
#  '_ResourceId': {'LXPATH_REGEX': 1.0, 'RESOURCEID_REGEX': 1.0}}
# OfficeActivity
# --------------
# {'AADGroupId': {'GUID_REGEX': 1.0},
#  'AppId': {'GUID_REGEX': 1.0},
#  'ClientAppId': {'GUID_REGEX': 1.0},
#  'ClientIP': {'IPV4_REGEX': 0.9, 'IPV6_REGEX': 0.1},
#  'ClientIP_': {'IPV4_REGEX': 0.9, 'IPV6_REGEX': 0.1},
#  'Client_IPAddress': {'IPV4_REGEX': 0.7727272727272727,
#                       'IPV6_REGEX': 0.22727272727272727},
#  'LogonUserSid': {'SID_REGEX': 1.0},
#  'MailboxGuid': {'GUID_REGEX': 1.0},
#  'MailboxOwnerSid': {'SID_REGEX': 1.0},
#  'MailboxOwnerUPN': {'EMAIL_REGEX': 1.0},
#  'OfficeId': {'GUID_REGEX': 1.0},
#  'OfficeObjectId': {'DNS_REGEX': 0.5925925925925926,
#                     'GUID_REGEX': 0.09259259259259259,
#                     'URL_REGEX': 0.1111111111111111},
#  'OrganizationId': {'GUID_REGEX': 1.0},
#  'OrganizationId_': {'GUID_REGEX': 1.0},
#  'OrganizationName': {'DNS_REGEX': 1.0},
#  'Site_': {'GUID_REGEX': 1.0},
#  'Site_Url': {'URL_REGEX': 1.0},
#  'Site_Url_': {'URL_REGEX': 1.0},
#  'SourceFileName': {'DNS_REGEX': 0.15384615384615385},
#  'SourceFileName_': {'DNS_REGEX': 0.15384615384615385},
#  'SourceRecordId': {'GUID_REGEX': 1.0},
#  'TargetUserOrGroupName': {'DNS_REGEX': 0.25, 'SHA256_REGEX': 0.5},
#  'TenantId': {'GUID_REGEX': 1.0},
#  'UserId': {'EMAIL_REGEX': 0.59, 'NTACCT_REGEX': 0.32},
#  'UserId_': {'EMAIL_REGEX': 0.59, 'NTACCT_REGEX': 0.32},
#  'UserKey': {'GUID_REGEX': 0.02, 'NTACCT_REGEX': 0.32}}
# CommonSecurityLog
# -----------------
# {'DestinationHostName': {'DNS_REGEX': 0.9893162393162394,
#                          'IPV4_REGEX': 0.004273504273504274,
#                          'MD5_REGEX': 0.004273504273504274},
#  'DestinationIP': {'IPV4_REGEX': 1.0},
#  'DestinationTranslatedAddress': {'IPV4_REGEX': 1.0},
#  'DeviceCustomString5': {'DNS_REGEX': 0.00641025641025641},
#  'Message': {'DNS_REGEX': 0.8318181818181818},
#  'RequestContext': {'DNS_REGEX': 0.8193384223918575,
#                     'MD5_REGEX': 0.022900763358778626},
#  'RequestURL': {'DNS_REGEX': 0.6811145510835913,
#                 'IPV4_REGEX': 0.006191950464396285,
#                 'MD5_REGEX': 0.006191950464396285},
#  'SourceIP': {'IPV4_REGEX': 0.997},
#  'SourceTranslatedAddress': {'IPV4_REGEX': 1.0},
#  'SourceUserName': {'EMAIL_REGEX': 0.8311965811965812},
#  'TenantId': {'GUID_REGEX': 1.0},
#  '_ResourceId': {'LXPATH_REGEX': 1.0, 'RESOURCEID_REGEX': 1.0}}

# %%
table_regexes
# Out:
# {'UserAccessAnalytics': {'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#   'AADTenantId': {'GUID_REGEX': (1.0, 1.0)},
#   'SourceEntityId': {'GUID_REGEX': (1.0, 1.0)},
#   'SourceEntityName': {'SHA256_REGEX': (0.010416666666666666, 0.01),
#    'GUID_REGEX': (0.041666666666666664, 0.04)},
#   'TargetEntityId': {'GUID_REGEX': (1.0, 1.0)},
#   'AccessId': {'GUID_REGEX': (1.0, 0.24)}},
#  'Usage': {'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#   'ResourceUri': {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)},
#   'MeterId': {'GUID_REGEX': (1.0, 1.0)},
#   'LinkedMeterId': {'GUID_REGEX': (1.0, 1.0)}},
#  'UpdateSummary': {'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#   'MG': {'GUID_REGEX': (1.0, 1.0)},
#   'SourceComputerId': {'GUID_REGEX': (1.0, 1.0)},
#   'Computer': {'DNS_REGEX': (0.39, 0.39)},
#   'SubscriptionId': {'GUID_REGEX': (1.0, 1.0)},
#   'ResourceProvider': {'DNS_REGEX': (1.0, 1.0)},
#   'ResourceId': {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)},
#   'VMUUID': {'GUID_REGEX': (1.0, 1.0)},
#   '_ResourceId': {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)}}}

# %%
def interpret_matches(table_match_dic):
    """For each column apply priority and match percentage logic to assign an entity to the column.
        
    Args:
        table_match_dic (Dict): Output of match_entities function. Dict showing all columns that matched one or more regexes.
    Returns:
        Dictionary: {Table: {Column: Entity}}
    """
    entity_assignments = {}
    for table, cols in table_match_dic.items():
        entity_assignments[table] = {}
        for col, matches in cols.items(): 
            highest_perc = 0
            highest_pri = 3
            isMatch = False
            for rgx_match, perc_match in matches.items():
                # Ignore GUID matches
                if rgx_match == "GUID_REGEX":
                    continue
                # Choose entity corresponding to the regex with the highest total match percentage
                # If tie, choose entity with highest priority
                # 0 has highest priority, 2 is the lowest
                isMatch = True
                regex_priority = int(entity_regexes.get(rgx_match, {}).get("priority", 0))
                regex = rgx_match
                if regex_priority < highest_pri:
                    highest_pri = regex_priority
                    rgx = rgx_match
                if perc_match[0] > highest_perc == True:
                    highest_perc = perc_match
                    regex = rgx_match
                elif perc_match[0] == highest_perc:
                    regex = rgx
            if(isMatch):
                entity_name = entity_regexes.get(regex, {}).get("entity")
                entity_assignments[table][col] = entity_name

    return entity_assignments

# %%
table_entities = interpret_matches(table_regexes)

for table, cols in table_entities.items():
    print(table)
    
    print("-" * len(table))
    pprint.pprint(cols)
# Out:
# SigninLogs
# ----------
# {'AlternateSignInName': 'account',
#  'AppDisplayName': 'host',
#  'IPAddress': 'ipaddress',
#  'Resource': 'host',
#  'ResourceGroup': 'host',
#  'ResourceId': 'azureresource',
#  'SignInIdentifier': 'account',
#  'UserPrincipalName': 'account'}
# SecurityEvent
# -------------
# {'Account': 'account',
#  'Computer': 'host',
#  'FileHash': 'hash',
#  'FilePath': 'account',
#  'IpAddress': 'ipaddress',
#  'MandatoryLabel': 'account',
#  'NewProcessName': 'process',
#  'ObjectName': 'file',
#  'ParentProcessName': 'process',
#  'Process': 'process',
#  'ProcessName': 'process',
#  'SubjectAccount': 'account',
#  'SubjectUserSid': 'account',
#  'TargetAccount': 'account',
#  'TargetUser': 'account',
#  'TargetUserSid': 'account',
#  '_ResourceId': 'azureresource'}
# OfficeActivity
# --------------
# {'ClientIP': 'ipaddress',
#  'ClientIP_': 'ipaddress',
#  'Client_IPAddress': 'ipaddress',
#  'LogonUserSid': 'account',
#  'MailboxOwnerSid': 'account',
#  'MailboxOwnerUPN': 'account',
#  'OfficeObjectId': 'url',
#  'OrganizationName': 'host',
#  'Site_Url': 'url',
#  'Site_Url_': 'url',
#  'SourceFileName': 'host',
#  'SourceFileName_': 'host',
#  'TargetUserOrGroupName': 'hash',
#  'UserId': 'account',
#  'UserId_': 'account',
#  'UserKey': 'account'}
# CommonSecurityLog
# -----------------
# {'DestinationHostName': 'ipaddress',
#  'DestinationIP': 'ipaddress',
#  'DestinationTranslatedAddress': 'ipaddress',
#  'DeviceCustomString5': 'host',
#  'RequestURL': 'host',
#  'SourceIP': 'ipaddress',
#  'SourceTranslatedAddress': 'ipaddress',
#  'SourceUserName': 'account',
#  '_ResourceId': 'azureresource'}

# %%
def create_entity_index(data):
    """Iterates through the interpreted results to create a dict keyed by entity type.

    Args:
        data (Dict): Output of interpret_matches function. Dict of column-entity mappings keyed by table and column.

    Returns:
        Dict: {entity: [(table, col)]}
    """
    entity_dict = {}
    for table, cols in data.items():
        for col, entity in cols.items():
            entity_dict[entity] = []
    for table, cols in data.items():
        for col, entity in cols.items():
            entity_dict[entity].append((table, col))
    return entity_dict

# %%
key_entity_dict = create_entity_index(table_entities)

import pprint
for entity, tables_cols in key_entity_dict.items():
    print(entity)
    
    print("-" * len(entity))
    pprint.pprint(tables_cols)
# Out:
# azureresource
# -------------
# [('SigninLogs', 'ResourceId'),
#  ('SecurityEvent', '_ResourceId'),
#  ('CommonSecurityLog', '_ResourceId')]
# host
# ----
# [('SigninLogs', 'Resource'),
#  ('SigninLogs', 'ResourceGroup'),
#  ('SigninLogs', 'AppDisplayName'),
#  ('SecurityEvent', 'Computer'),
#  ('OfficeActivity', 'SourceFileName'),
#  ('OfficeActivity', 'SourceFileName_'),
#  ('OfficeActivity', 'OrganizationName'),
#  ('CommonSecurityLog', 'RequestURL'),
#  ('CommonSecurityLog', 'DeviceCustomString5')]
# account
# -------
# [('SigninLogs', 'AlternateSignInName'),
#  ('SigninLogs', 'UserPrincipalName'),
#  ('SigninLogs', 'SignInIdentifier'),
#  ('SecurityEvent', 'Account'),
#  ('SecurityEvent', 'FilePath'),
#  ('SecurityEvent', 'MandatoryLabel'),
#  ('SecurityEvent', 'SubjectAccount'),
#  ('SecurityEvent', 'SubjectUserSid'),
#  ('SecurityEvent', 'TargetAccount'),
#  ('SecurityEvent', 'TargetUser'),
#  ('SecurityEvent', 'TargetUserSid'),
#  ('OfficeActivity', 'UserKey'),
#  ('OfficeActivity', 'UserId'),
#  ('OfficeActivity', 'UserId_'),
#  ('OfficeActivity', 'MailboxOwnerUPN'),
#  ('OfficeActivity', 'MailboxOwnerSid'),
#  ('OfficeActivity', 'LogonUserSid'),
#  ('CommonSecurityLog', 'SourceUserName')]
# ipaddress
# ---------
# [('SigninLogs', 'IPAddress'),
#  ('SecurityEvent', 'IpAddress'),
#  ('OfficeActivity', 'ClientIP'),
#  ('OfficeActivity', 'ClientIP_'),
#  ('OfficeActivity', 'Client_IPAddress'),
#  ('CommonSecurityLog', 'DestinationIP'),
#  ('CommonSecurityLog', 'SourceIP'),
#  ('CommonSecurityLog', 'DestinationTranslatedAddress'),
#  ('CommonSecurityLog', 'DestinationHostName'),
#  ('CommonSecurityLog', 'SourceTranslatedAddress')]
# hash
# ----
# [('SecurityEvent', 'FileHash'), ('OfficeActivity', 'TargetUserOrGroupName')]
# process
# -------
# [('SecurityEvent', 'NewProcessName'),
#  ('SecurityEvent', 'ParentProcessName'),
#  ('SecurityEvent', 'Process'),
#  ('SecurityEvent', 'ProcessName')]
# file
# ----
# [('SecurityEvent', 'ObjectName')]
# url
# ---
# [('OfficeActivity', 'OfficeObjectId'),
#  ('OfficeActivity', 'Site_Url'),
#  ('OfficeActivity', 'Site_Url_')]

# %%
output_regexes = {}

for i in range(3):
    table, cols = qry_prov.schema.popitem()
    df = qry_prov.exec_query(f"{table} | sample 100")
    while len(df) == 0:
        table, cols = qry_prov.schema.popitem()
        df = qry_prov.exec_query(f"{table} | sample 100")
    output_regexes[table] = match_regexes(df)
output_entities = interpret_matches(output_regexes)
keyed_entities = create_entity_index(output_entities)
        
for entity, tables_cols in keyed_entities.items():
    print(entity)
    
    print("-" * len(entity))
    pprint.pprint(tables_cols)
# Out:
# azureresource
# -------------
# [('SecurityNestedRecommendation', 'AssessedResourceId'),
#  ('SecurityNestedRecommendation', 'Id'),
#  ('SecurityEvent', '_ResourceId')]
# url
# ---
# [('SecurityNestedRecommendation', 'RemediationDescription'),
#  ('SecurityIncident', 'IncidentUrl')]
# account
# -------
# [('SecurityEvent', 'Account'),
#  ('SecurityEvent', 'FilePath'),
#  ('SecurityEvent', 'MandatoryLabel'),
#  ('SecurityEvent', 'ObjectName'),
#  ('SecurityEvent', 'SubjectAccount'),
#  ('SecurityEvent', 'SubjectUserSid'),
#  ('SecurityEvent', 'TargetAccount'),
#  ('SecurityEvent', 'TargetSid'),
#  ('SecurityEvent', 'TargetUser'),
#  ('SecurityEvent', 'TargetUserSid')]
# host
# ----
# [('SecurityEvent', 'Computer'), ('SecurityEvent', 'TargetUserName')]
# hash
# ----
# [('SecurityEvent', 'FileHash')]
# ipaddress
# ---------
# [('SecurityEvent', 'IpAddress')]
# process
# -------
# [('SecurityEvent', 'NewProcessName'),
#  ('SecurityEvent', 'ParentProcessName'),
#  ('SecurityEvent', 'Process'),
#  ('SecurityEvent', 'ProcessName')]

# %% [markdown]
# # Autogenerating queries

# %%
query_template = """
{table}
| where TimeGenerated > ago(1d)
| where {ColumnName} == "{{MySearch}}"
"""

# %%
table_regexes
# Out:
# {'SigninLogs': {'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#   'ResourceId': {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)},
#   'CorrelationId': {'GUID_REGEX': (1.0, 1.0)},
#   'Resource': {'DNS_REGEX': (1.0, 1.0)},
#   'ResourceGroup': {'DNS_REGEX': (1.0, 1.0)},
#   'AlternateSignInName': {'EMAIL_REGEX': (1.0, 0.34)},
#   'AppDisplayName': {'DNS_REGEX': (0.01, 0.01)},
#   'AppId': {'GUID_REGEX': (1.0, 1.0)},
#   'Id': {'GUID_REGEX': (1.0, 1.0)},
#   'IPAddress': {'IPV4_REGEX': (0.94, 0.94), 'IPV6_REGEX': (0.06, 0.06)},
#   'OriginalRequestId': {'GUID_REGEX': (1.0, 1.0)},
#   'ResourceIdentity': {'GUID_REGEX': (1.0, 0.95)},
#   'UserId': {'GUID_REGEX': (1.0, 1.0)},
#   'UserPrincipalName': {'EMAIL_REGEX': (1.0, 1.0)},
#   'AADTenantId': {'GUID_REGEX': (1.0, 1.0)},
#   'SignInIdentifier': {'EMAIL_REGEX': (1.0, 0.34)},
#   'ResourceTenantId': {'GUID_REGEX': (1.0, 1.0)},
#   'HomeTenantId': {'GUID_REGEX': (1.0, 0.98)}},
#  'SecurityEvent': {'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#   'Account': {'WINPATH_REGEX': (0.3076923076923077, 0.28),
#    'NTACCT_REGEX': (0.6923076923076923, 0.63)},
#   'Computer': {'DNS_REGEX': (0.51, 0.51)},
#   'SourceComputerId': {'GUID_REGEX': (1.0, 1.0)},
#   'EventOriginId': {'GUID_REGEX': (1.0, 1.0)},
#   'MG': {'GUID_REGEX': (1.0, 1.0)},
#   'FileHash': {'SHA256_REGEX': (1.0, 0.28)},
#   'FilePath': {'NTACCT_REGEX': (0.6428571428571429, 0.18)},
#   'IpAddress': {'IPV4_REGEX': (0.9444444444444444, 0.34)},
#   'LogonGuid': {'GUID_REGEX': (1.0, 0.02)},
#   'MandatoryLabel': {'SID_REGEX': (1.0, 0.15)},
#   'NewProcessName': {'WINPATH_REGEX': (1.0, 0.15),
#    'WINPROCESS_REGEX': (1.0, 0.15)},
#   'ObjectName': {'WINPATH_REGEX': (0.75, 0.06)},
#   'ParentProcessName': {'WINPATH_REGEX': (1.0, 0.15),
#    'WINPROCESS_REGEX': (1.0, 0.15)},
#   'Process': {'DNS_REGEX': (0.6091954022988506, 0.53),
#    'WINPROCESS_REGEX': (0.6091954022988506, 0.53)},
#   'ProcessName': {'WINPATH_REGEX': (0.22727272727272727, 0.1),
#    'WINPROCESS_REGEX': (0.22727272727272727, 0.1)},
#   'SubjectAccount': {'NTACCT_REGEX': (0.4603174603174603, 0.29)},
#   'SubjectUserSid': {'SID_REGEX': (1.0, 0.63)},
#   'TargetAccount': {'WINPATH_REGEX': (0.5283018867924528, 0.28),
#    'NTACCT_REGEX': (0.18867924528301888, 0.1)},
#   'TargetLogonGuid': {'GUID_REGEX': (1.0, 0.01)},
#   'TargetUser': {'SID_REGEX': (1.0, 0.28)},
#   'TargetUserSid': {'SID_REGEX': (1.0, 0.5)},
#   '_ResourceId': {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)}},
#  'OfficeActivity': {'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#   'OrganizationId': {'GUID_REGEX': (1.0, 1.0)},
#   'OrganizationId_': {'GUID_REGEX': (1.0, 1.0)},
#   'UserKey': {'NTACCT_REGEX': (0.1, 0.1), 'GUID_REGEX': (0.02, 0.02)},
#   'OfficeObjectId': {'URL_REGEX': (0.1111111111111111, 0.06),
#    'GUID_REGEX': (0.09259259259259259, 0.05)},
#   'UserId': {'EMAIL_REGEX': (0.59, 0.59), 'NTACCT_REGEX': (0.1, 0.1)},
#   'UserId_': {'EMAIL_REGEX': (0.59, 0.59), 'NTACCT_REGEX': (0.1, 0.1)},
#   'ClientIP': {'IPV4_REGEX': (0.5666666666666667, 0.17),
#    'IPV6_REGEX': (0.1, 0.03)},
#   'ClientIP_': {'IPV4_REGEX': (0.5666666666666667, 0.17),
#    'IPV6_REGEX': (0.1, 0.03)},
#   'Site_': {'GUID_REGEX': (1.0, 0.17)},
#   'Site_Url': {'URL_REGEX': (1.0, 0.14)},
#   'Site_Url_': {'URL_REGEX': (1.0, 0.14)},
#   'SourceFileName': {'DNS_REGEX': (0.15384615384615385, 0.02)},
#   'SourceFileName_': {'DNS_REGEX': (0.15384615384615385, 0.02)},
#   'OrganizationName': {'DNS_REGEX': (1.0, 0.76)},
#   'MailboxGuid': {'GUID_REGEX': (1.0, 0.44)},
#   'MailboxOwnerUPN': {'EMAIL_REGEX': (1.0, 0.44)},
#   'MailboxOwnerSid': {'SID_REGEX': (1.0, 0.44)},
#   'LogonUserSid': {'SID_REGEX': (1.0, 0.44)},
#   'Client_IPAddress': {'IPV4_REGEX': (0.7727272727272727, 0.34),
#    'IPV6_REGEX': (0.22727272727272727, 0.1)},
#   'OfficeId': {'GUID_REGEX': (1.0, 1.0)},
#   'SourceRecordId': {'GUID_REGEX': (1.0, 1.0)},
#   'TargetUserOrGroupName': {'SHA256_REGEX': (0.5, 0.02)},
#   'AADGroupId': {'GUID_REGEX': (1.0, 0.02)},
#   'AppId': {'GUID_REGEX': (1.0, 0.51)},
#   'ClientAppId': {'GUID_REGEX': (1.0, 0.17)}},
#  'CommonSecurityLog': {'TenantId': {'GUID_REGEX': (1.0, 1.0)},
#   'DestinationIP': {'IPV4_REGEX': (1.0, 1.0)},
#   'SourceIP': {'IPV4_REGEX': (0.997, 0.997)},
#   'DestinationTranslatedAddress': {'IPV4_REGEX': (1.0, 0.121)},
#   'DestinationHostName': {'DNS_REGEX': (0.9893162393162394, 0.463),
#    'IPV4_REGEX': (0.004273504273504274, 0.002)},
#   'RequestURL': {'DNS_REGEX': (0.006191950464396285, 0.002)},
#   'SourceTranslatedAddress': {'IPV4_REGEX': (1.0, 0.57)},
#   'SourceUserName': {'EMAIL_REGEX': (0.8311965811965812, 0.389)},
#   'DeviceCustomString5': {'DNS_REGEX': (0.00641025641025641, 0.003)},
#   '_ResourceId': {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)}}}

# %%
def generate_query(entity_type, search_value):
    email_queries = []
    for table, matches in table_regexes.items():
        for col, regexes in matches.items():
            print(regexes)
            if entity_type in regexes.keys():

                for label, entity in regexes.items():
                    if entity_type == entity:
                        print("found match", table, col, entity)
                        query = query_template.format(table=table, ColumnName=col)
                        email_queries.append(query.format(MySearch=search_value))
    return email_queries

# %%
queries=generate_query("EMAIL_REGEX", "michelle.duncan@conocophillips.com")
print(queries)
# Out:
# {'GUID_REGEX': (1.0, 1.0)}
# {'GUID_REGEX': (1.0, 1.0)}
# {'GUID_REGEX': (1.0, 1.0)}
# {'GUID_REGEX': (1.0, 1.0)}
# {'GUID_REGEX': (1.0, 1.0)}
# {'GUID_REGEX': (1.0, 1.0)}
# {'DNS_REGEX': (1.0, 1.0)}
# {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)}
# {'GUID_REGEX': (1.0, 1.0)}
# {'LXPATH_REGEX': (1.0, 1.0), 'RESOURCEID_REGEX': (1.0, 1.0)}
# []

# %%
for query in queries:
    query_result=qry_prov.exec_query(query)
    print(query)
    print("-" * len(query))
    display(query_result)
